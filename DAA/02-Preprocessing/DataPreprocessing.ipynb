# %% [markdown]
# # Exercise Data Preprocessing of the lecture Digitization and Data Analytics

# %% [markdown]
# Content
#
# - Feature Extraction
# - Data Transformation
# - Data Type Porting
# - Data Reduction

# %% [markdown]
# ## Preparation
# **Local Environment**:
# This exercise may be conducted on your local environment, using the Docker Solution described in Docker-Walkthrough.html.
# Download exercises into your working directory.
#
# **HPC Environment**:
# This exercise may be conducted on the HPC infrastructure at ZIH, using the Jupyter Hub, described in JupyterHub-Walkthrough.html. However, the HPC cluster is under maintenance until the 6th of May.
#
# ### Data
# **Local Environment**:
# The data, necessary for this exercises are uploaded in OPAL:Exercises/DataPreprocessing/
#
# **HPC Environment**:
# The data, necessary for this exercises are uploaded in /projects/p_lv_dda_2022/preprocessing/data on **taurus**.

# %% [markdown]
# ## Exercise 1 Feature Extraction

# %% [markdown]
# What do the following calls?
# - CountVectorizer
# - vectorizer.fit(text)
# - print(vectorizer.vocabulary_)
# - vectorizer.transform(text)
#
# Have a look at https://scikit-learn.org/stable/
#
# Run the following program:

# %%
from sklearn.feature_extraction.text import CountVectorizer
# list of text documents
text = ["The quick brown fox jumped over the lazy dog."]
# create the transform
vectorizer = CountVectorizer()
# tokenize and build vocab
vectorizer.fit(text)
# summarize
print(vectorizer.vocabulary_)
# encode document
vector = vectorizer.transform(text)
# summarize encoded vector
print(vector.shape)
print(type(vector))
print(vector.toarray())

# %% [markdown]
# How does the output look like if you encode text2 = [“the puppy”]?

# %% [markdown]
# What do you need to do to include the words of text2 into the
# vocabulary?

# %% [markdown]
# How does the output look like if you add two or more documents?

# %% [markdown]
# ## Exercise 2 Data Transformation/Data Type Porting

# %% [markdown]
# Have a look at the data set pima-indians-diabetes.data.csv
#
# https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv
#
# https://www.kaggle.com/uciml/pima-indians-diabetes-database/data

# %% [markdown]
# Documentation on the preprocessing library will be found on https://scikit-learn.org/stable/

# %% [markdown]
# ### Min-Max Scaling
#
# Run the following program MinMaxScaler.py and understand each step of the program.

# %%
# MinMaxScaler.py

# Rescale data (between 0 and 1)
import pandas
import scipy
import numpy
from sklearn.preprocessing import MinMaxScaler
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pandas.read_csv(url, names=names)
array = dataframe.values
# separate array into input and output components
X = array[:,0:8]
Y = array[:,8]
scaler = MinMaxScaler(feature_range=(0, 1))
rescaledX = scaler.fit_transform(X)
# summarize transformed data
numpy.set_printoptions(precision=3)
print(rescaledX[0:5,:])

# %% [markdown]
# Modify the program such that ageIncome.csv will be
# scaled.

# %% [markdown]
# ### Standard Scaler
#
# Run the program StandardScaler.py and understand each step of the program.
# How are the data transformed?

# %%
# StandardScaler.py

# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas
import numpy
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pandas.read_csv(url, names=names)
array = dataframe.values
# separate array into input and output components
X = array[:,0:8]
Y = array[:,8]
scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)
# summarize transformed data
numpy.set_printoptions(precision=3)
print(rescaledX[0:20,:])

plt.figure()
dataframe[['preg', 'plas', 'pres']].plot(kind = 'hist')
#dataframe[['preg']].plot(kind = 'hist')  
#dataframe.plot(kind = 'hist') # all attributes
plt.show()


# =============================================================================
# col_sel = 0
# plotdat = rescaledX[:,col_sel]
# plt.hist(plotdat) #, bins=numpy.sqrt(plotdat.shape[0]))
# plt.title("Histogram column " + str(col_sel))
# plt.show()
# =============================================================================

# %% [markdown]
# - Modify the program by uncommenting line 21/22 and 26 to 31

# %% [markdown]
# ### Normalizer
#
# Run the program Normalizer.py and understand each step of the program.
# How are the data transformed?

# %%
# Normalize data (length of 1)
from sklearn.preprocessing import Normalizer
import pandas
import numpy
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pandas.read_csv(url, names=names)
array = dataframe.values
# separate array into input and output components
X = array[:,0:8]
Y = array[:,8]
scaler = Normalizer().fit(X)
normalizedX = scaler.transform(X)
# summarize transformed data
numpy.set_printoptions(precision=3)
print(normalizedX[0:20,:])

# Test
#length = numpy.linalg.norm(normalizedX[2])
#print(length)

# %% [markdown]
# Test the output by calculating the length of some feature
# vectors.

# %% [markdown]
# ### Binarizer
#
# Run the program Binarizer.py and understand each step of the program.
# How are the data transformed?

# %%
#Binarizer.py

# binarization
from sklearn.preprocessing import Binarizer
import pandas
import numpy
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pandas.read_csv(url, names=names)
array = dataframe.values
# separate array into input and output components
X = array[:,0:8]
Y = array[:,8]
binarizer = Binarizer(threshold=0.0).fit(X)
binaryX = binarizer.transform(X)
# summarize transformed data
numpy.set_printoptions(precision=3)
print(binaryX[0:5,:])

# %% [markdown]
# Change the threshold for binarizing.

# %% [markdown]
# Further hints: Compare scaling methods
# (see
# http://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html )

# %% [markdown]
# ## Exercise 3 Data Reduction (Singular Value Decomposition)

# %% [markdown]
# Run the following program DataReduction.py, which you already know from above.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from numpy import array
from numpy import diag
from numpy import zeros
from scipy.linalg import svd
from sklearn.decomposition import TruncatedSVD

# list of text documents
text = ["The quick brown fox jumped over the lazy dog and the puppy.", "This spring is amazingly warm.", "The cat likes this icecream."]
# create the transform
vectorizer = CountVectorizer()
# tokenize and build vocab
vectorizer.fit(text)
# summarize
print(vectorizer.vocabulary_)
# encode document
vector = vectorizer.transform(text)
# summarize encoded vector
print(vector.shape)
print(type(vector))
#print(vector.toarray())

A = vector.toarray()
print(A)

# %% [markdown]
# Uncomment Part 1 to 5 one after the other in order to investigate the different parts of the Decomposition.
# **Exercise**: What happens in part 1?

# %%
'''
# Part 1
U, s, VT = svd(A)
print(U)
print(s)
print(VT)
'''

# %% [markdown]
# **Exercise**: In which line, the data reduction actually happens?

# %%
'''
# Part 2
# Data Reduction 
# create m x n Sigma matrix
Sigma = zeros((A.shape[0], A.shape[1]))
# populate Sigma with n x n diagonal matrix given by s
Sigma[:A.shape[0], :A.shape[0]] = diag(s)
# select
n_elements = 2
Sigma = Sigma[:, :n_elements]
print(Sigma)
'''

# %%
'''
# Part 3
# consider only a part of VT
VT = VT[:n_elements, :]
print(VT)
'''

# %% [markdown]
# **Exercise**: Analyse the output of the variable T and explain.

# %%
'''
Part 4
# reconstruct
B = U.dot(Sigma.dot(VT))
print(B)
# transform
T = U.dot(Sigma)
print(T)
T = A.dot(VT.T)
print(T)
'''

# %% [markdown]
# **Exercise**: Explain, what you observe.

# %%
'''
# Part 5
# Data reduction with sklearn
print(A)
# svd
svd = TruncatedSVD(n_components=3)
svd.fit(A)
result = svd.transform(A)
print(result)
'''

# %% [markdown]
# Useful links:
# - https://machinelearningmastery.com/start-here/
# - http://scikit-learn.org/stable/

# %% [markdown]
# ## Exercise 4 Complex task (time series)

# %% [markdown]
# ![Coin image](./euro_coin.jpeg)

# %% [markdown]
# The dataset under consideration contains ultrasound measurements from Euro coins. The dataset was created by Steffen Seitz from the chair of Fundamentals of Electrical Engineering at the Technische Universität Dresden, Germany. Thanks to him for providing us this dataset.
#
# Description of the dataset:
#
# 1. One measurement is a time series comprising approximately 3 seconds (a bit more) with a sampling rate of ~204 kHz. Concretely, a single time series consists of approximately 600,000-800,000 discrete voltage measurments (in mV).
# 1. Every time series is stored in a single file, containing the voltages as comma separated values in the first row. The single files are at the subfolder coindata_selection.
# 1. The file name contains the coin category in the first numbers before the first underscore, e.g. 5_tisch_g16_100, 20_tisch_g8_01 contain measurements of a 5 cent and a 20 cent coin resp. Hint: 10 cent coins are not contained in the dataset.

# %% [markdown]
# ## Task: Plot the time series as raw data for every coin category
# Hint: One time step is $1/204,000\ s \approx 0.005\ ms$ (cp. sampling rate). For sake of simplicity just think of time steps and choose integer values (x-axis).

# %% [markdown]
# ## Task: Apply a fast Fourier transform to the time series for getting the corresponding spectral density and plot the spectral densities for the different coin categories.
# Hint: For the Fourier transform use the fast Fourier transform for real input from numpy or scipy, e.g. numpy.abs(rfft(your_time_series_array)). For sake of simplicity, we don't care about the frequency axis in detail.

# %% [markdown]
# ## Task: Collect all spectral densities (including the coin category) into one data object (e.g. a dataframe).

# %% [markdown]
# ## Task: Think about data dimension for every spectrum. Is it appropriate/useful/neccessary?

# %% [markdown]
# ## Task: How would you normalize that spectral data?
