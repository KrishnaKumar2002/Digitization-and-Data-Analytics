# %% [markdown]
# # Welcome to the DDA exercise
#
# ---
#
# ## Organization of the exercise
#
# 1. You will work in groups of 3 students. These groups persist for the whole semester.
# 2. We will provide you with the material for the next exercise one week in advance.
#    1. The groups will have one week to prepare the exercise
#    2. Each week, some groups will present their solutions in the exercise
# 3. The Thursday slot consists of two parts:
#    1. Group presentations of the exercise
#    2. Time to work on the next exercise
#
# ## Schedule
#
# | Exercise # | Topic                                                   | Date                                 |
# | ---------- | ------------------------------------------------------- | ------------------------------------ |
# | 1          | Introduction                                            | 23.04                                |
# | -          | <span style="color:red">Self study - no exercise</span> | <span style="color:red">30.04</span> |
# | 2          | Preprocessing                                           | 07.05                                |
# | -          | <span style="color:red">Himmelfahrt</span>              | <span style="color:red">14.05</span> |
# | 3          | Basics of Statistics                                    | 21.05                                |
# | -          | <span style="color:red">Pfingsten</span>              | <span style="color:red">28.05</span> |
# | 4          | Machine Learning I                                      | 04.06                                |
# | 5          | Machine Learning II                                     | 11.06                                |
# | 6          | Machine Learning III                                    | 18.06                                |
# | 7          | Machine Learning IV                                     | 25.06                                |
# | 8          | Distributed Computing I                                 | 02.07                                |
# | 9          | Distributed Computing II                                | 09.07                                |
# | 10         | Distributed Computing III                               | 16.07                                |
#
# ---
#
# ## How To: Exercises
#
# All the notebooks will use the HPC machine at ZIH. Nevertheless, you can also use your local setup to solve the tasks.
#
# For local setup, please check: `Docker-Walkthrough.html`
#
# ### Access to HPC
#
# Please register via the following link:
#
# https://tud.link/tphpzj
#
# ![kurzlink_qrcode.png](attachment:kurzlink_qrcode.png)
#
# Note, after you registered it might take a while until your HPC login is active.
#
# ### Access to the exercise material on HPC
#
# Exercises will be uploaded to Opal and directly to the HPC in the <span style="color:coral; font-family: monospace;">/projects/p_lv_dda_26</span> directory. Please copy the data to your <span style="color:green; font-family: monospace;">$HOME</span> directory, e.g.
#
# ```bash
# cp -R "/projects/p_lv_dda_26/01-Introduction" "${HOME}/"
# ```
#
# Now, open the notebook and run the cells/solve the tasks. Most notebooks run the **PyTorch v1.x (Machine Learning)** kernel. Some notebooks will tell you to choose another.
#
# ---
#
# ## Example: 00 - Introduction
#
# 1. Go to [jupyterhub.hpc.tu-dresden.de](https://jupyterhub.hpc.tu-dresden.de) <br>
#    Note: This is accessible only within university network. Use [VPN](https://tu-dresden.de/zih/dienste/service-katalog/arbeitsumgebung/zugang_datennetz/vpn#section-4) if you are accessing HPC from outside the University's network.
# 2. Select "Advanced" and use the following parameters:
#    - Partition: romeo
#    - CPUs per task: 2
#    - Memory per CPU: 4096
#    - Runtime: 01:30:00
#    - _Hint_: For the time of the exercise, you can use a reservation to get your resources immediately. <br>
#      We have the exclusively reserved resources for our exercises (start time 11:00, end time 13:00). The reservation is accessiblg using reservation IDs which will be provided by tutors of the respective exercises.
#
# ![grafik.png](attachment:b8c1bcdb-e401-4282-a042-155be18e7fbc.png)
#
# 3. Use the Terminal and the `cp` command to copy the exercise material into your $HOME directory
#
# ![grafik.png](attachment:060d5b07-f8ff-4849-b549-a716e4415262.png) ![Screenshot_20260416_123435-2.png](attachment:Screenshot_20260416_123435-2.png)
#
# 4. Select the jupyter notebook (.ipynb) and run it with the `PyTorch v1.x (Machine Learning)` kernel. For kernel selection, click on the name of the kernel on the top right and select the kernel in the drop-down menu.
#
# ![grafik.png](attachment:ac71ed4d-e3b4-4425-9cdf-7b57accb9aa1.png)
# ![grafik.png](attachment:762cfbce-d715-4aa2-bd7a-702a15c92425.png)
#
# ---
#
# ## Hints
#
# - **Participate in the exercise regularly.** We can answer questions and provide guidance if things are not working. You will also have reserved HPC resources.
# - Find help in the HPC compendium: https://doc.zih.tu-dresden.de/
# - Make use of Youtube channels, ChatGPT and other sources additionally to learn about the topics
#
# ---
#
# ## Some Intro to Jupyter Notebooks
#
# Good to know tricks
#
# - Notebooks have 2 modes, view and edit similar to VIM text editor.
#   - Get comfortable with the shortcut keys.
#   - In view mode:
#     - 'a' to add a new cell above.
#     - 'b' to add a new cell below.
#     - 'Enter' to enter edit mode.
#     - 'dd' delete cell.
#   - In edit mode:
#     - 'Esc' to leave edit mode.
# - Use TAB / autocomplete feature of the Notebook for faster typing.
# - Use ! to run OS terminal specific commands such as ls, mkdir, ..
#
# ### Import an object from a library

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# #### Show the documentation for the object

# %%
# ?CountVectorizer

# %% [markdown]
# #### Show the documentation and the source code for the object

# %%
??CountVectorizer

# %% [markdown]
# #### List all the attributes and properties of an object

# %%
dir(CountVectorizer)

# %% [markdown]
# ---
#
# ## Numpy and Matplotlib

# %%
#imports
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#random data
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram
x = np.random.normal(size = 1000)
plt.hist(x, bins=60)
plt.gca().set(title='Frequency Histogram', ylabel='Frequency');

# %% [markdown]
# ### Hello World Example for sklearn
#
# Source: https://scikit-learn.org/stable/auto_examples/classification/plot_digits_classification.html#sphx-glr-auto-examples-classification-plot-digits-classification-py

# %%
# Author: Gael Varoquaux <gael dot varoquaux at normalesup dot org>
# License: BSD 3 clause

# Standard scientific Python imports
import matplotlib.pyplot as plt

# Import datasets, classifiers and performance metrics
from sklearn import datasets, metrics, svm
from sklearn.model_selection import train_test_split

# %%
digits = datasets.load_digits()

_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image, label in zip(axes, digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title("Training: %i" % label)

# %%
# flatten the images
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))

# Create a classifier: a support vector classifier
clf = svm.SVC(gamma=0.001)

# Split data into 50% train and 50% test subsets
X_train, X_test, y_train, y_test = train_test_split(
    data, digits.target, test_size=0.5, shuffle=False
)

# Learn the digits on the train subset
clf.fit(X_train, y_train)

# Predict the value of the digit on the test subset
predicted = clf.predict(X_test)

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image, prediction in zip(axes, X_test, predicted):
    ax.set_axis_off()
    image = image.reshape(8, 8)
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title(f"Prediction: {prediction}")

# %%
print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

# %%
disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
disp.figure_.suptitle("Confusion Matrix")
print(f"Confusion matrix:\n{disp.confusion_matrix}")

plt.show()
