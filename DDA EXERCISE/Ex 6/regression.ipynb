# %% [markdown]
# # Exercise - Digitization and Data Analytics - Machine Learning

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing, fetch_covtype
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.feature_selection import RFE

# %%
california = fetch_california_housing()
cover_type = fetch_covtype()

# Preparing the Dataset with Numerical Target variable
reg_data_without_target = pd.DataFrame(california.data, columns=california.feature_names)
reg_target = pd.DataFrame(california.target, columns=['House_Value'])
reg_data = pd.concat([reg_data_without_target, reg_target], axis=1)

# Preparing the Datset with Categorial Target variable
cla_data_without_target = pd.DataFrame(cover_type.data)
cla_target = pd.DataFrame(cover_type.target, columns=['Cover_Type'])
cla_data = pd.concat([cla_data_without_target, cla_target], axis=1)

# %% [markdown]
# ## Task 1 - Correlation Matrices

# %% [markdown]
# ### Compute the correlation matrices for the datasets and plot it to visualize the results.

# %% [markdown]
# ### Observing the the plots, what variables are strongly correlated?

# %% [markdown]
# ## Task 2 - Prinicple Component Analysis

# %% [markdown]
# ### Apply PCA (Principle Component Analysis) to the datasets.

# %% [markdown]
# ### How many Principle Components are sufficient for the given datasets?

# %% [markdown]
# ### Compare the result of this Task with the previous Task and write observations below.

# %% [markdown]
# ## Task 3 - t-SNE

# %% [markdown]
# ### Apply the t-SNE method to the data without the target variable. Reduce the number of features/ dimensions to 20.

# %% [markdown]
# ## Task 4 - Linear Regression

# %% [markdown]
# ### Build a Linear Regression model for the housing dataset, ie, `reg_data`

# %% [markdown]
# ### Using methods described in the lectures, assess if the model obtained is a good fit or bad fit to the dataset.

# %% [markdown]
# ### Apply backwards variable selection and compare with the previous model.

# %% [markdown]
# ### Apply Linear Regression to the Principle Components from Task 2.

# %% [markdown]
# ### Apply Linear Regression to the results obtained in Task 3.

# %% [markdown]
# ## Task 5 - Logistic Regression

# %% [markdown]
# ### Build a Logistic Regression model for the cover type dataset, ie, `cla_data`

# %% [markdown]
# ### Using the methods described in lectures, assess if the model obtained is a good fit or a bad fit to the dataset.

# %% [markdown]
# ### Apply backwards variable selection and compare with the previous model.

# %% [markdown]
# ### Apply Logistic Regression to the Principle Components from Task 2.

# %% [markdown]
# ### Apply Logistic Regression to the results obtained in Task 3.
